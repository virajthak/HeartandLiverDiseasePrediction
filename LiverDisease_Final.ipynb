# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data//Liver Patient Dataset (LPD)_train.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#    Age of the patient Gender of the patient  Total Bilirubin  \
# 0                65.0                Female              0.7
# 1                62.0                  Male             10.9
# 2                62.0                  Male              7.3
# 3                58.0                  Male              1.0
# 4                72.0                  Male              3.9
#
#    Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0               0.1                          187.0
# 1               5.5                          699.0
# 2               4.1                          490.0
# 3               0.4                          182.0
# 4               2.0                          195.0
#
#     Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                            16.0                             18.0
# 1                            64.0                            100.0
# 2                            60.0                             68.0
# 3                            14.0                             20.0
# 4                            27.0                             59.0
#
#    Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  Result
# 0             6.8           3.3                                  0.90       1
# 1             7.5           3.2                                  0.74       1
# 2             7.0           3.3                                  0.89       1
# 3             6.8           3.4                                  1.00       1
# 4             7.3           2.4                                  0.40       1

# %%
df.tail()
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 30686                50.0                  Male              2.2
# 30687                55.0                  Male              2.9
# 30688                54.0                  Male              6.8
# 30689                48.0                Female              1.9
# 30690                30.0                  Male              3.1
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 30686               1.0                          610.0
# 30687               1.3                          482.0
# 30688               3.0                          542.0
# 30689               1.0                          231.0
# 30690               1.6                          253.0
#
#         Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 30686                            17.0                             28.0
# 30687                            22.0                             34.0
# 30688                           116.0                             66.0
# 30689                            16.0                             55.0
# 30690                            80.0                            406.0
#
#        Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  \
# 30686             7.3           2.6                                  0.55
# 30687             7.0           2.4                                  0.50
# 30688             6.4           3.1                                  0.90
# 30689             4.3           1.6                                  0.60
# 30690             6.8           3.9                                  1.30
#
#        Result
# 30686       1
# 30687       1
# 30688       1
# 30689       1
# 30690       1

# %%
df.shape
# Out:
# (30691, 11)

# %%
df.columns
# Out:
# Index(['Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age of the patient                      float64
# Gender of the patient                    object
# Total Bilirubin                         float64
# Direct Bilirubin                        float64
#  Alkphos Alkaline Phosphotase           float64
#  Sgpt Alamine Aminotransferase          float64
# Sgot Aspartate Aminotransferase         float64
# Total Protiens                          float64
#  ALB Albumin                            float64
# A/G Ratio Albumin and Globulin Ratio    float64
# Result                                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30691 entries, 0 to 30690
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Age of the patient                    30689 non-null  float64
#  1   Gender of the patient                 29789 non-null  object
#  2   Total Bilirubin                       30043 non-null  float64
#  3   Direct Bilirubin                      30130 non-null  float64
#  4    Alkphos Alkaline Phosphotase         29895 non-null  float64
#  5    Sgpt Alamine Aminotransferase        30153 non-null  float64
#  6   Sgot Aspartate Aminotransferase       30229 non-null  float64
#  7   Total Protiens                        30228 non-null  float64
#  8    ALB Albumin                          30197 non-null  float64
#  9   A/G Ratio Albumin and Globulin Ratio  30132 non-null  float64
#  10  Result                                30691 non-null  int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#        Age of the patient  Total Bilirubin  Direct Bilirubin  \
# count        30689.000000     30043.000000      30130.000000
# mean            44.107205         3.370319          1.528042
# std             15.981043         6.255522          2.869592
# min              4.000000         0.400000          0.100000
# 25%             32.000000         0.800000          0.200000
# 50%             45.000000         1.000000          0.300000
# 75%             55.000000         2.700000          1.300000
# max             90.000000        75.000000         19.700000
#
#         Alkphos Alkaline Phosphotase   Sgpt Alamine Aminotransferase  \
# count                   29895.000000                    30153.000000
# mean                      289.075364                       81.488641
# std                       238.537589                      182.158850
# min                        63.000000                       10.000000
# 25%                       175.000000                       23.000000
# 50%                       209.000000                       35.000000
# 75%                       298.000000                       62.000000
# max                      2110.000000                     2000.000000
#
#        Sgot Aspartate Aminotransferase  Total Protiens   ALB Albumin  \
# count                     30229.000000    30228.000000  30197.000000
# mean                        111.469979        6.480237      3.130142
# std                         280.851078        1.081980      0.792281
# min                          10.000000        2.700000      0.900000
# 25%                          26.000000        5.800000      2.600000
# 50%                          42.000000        6.600000      3.100000
# 75%                          88.000000        7.200000      3.800000
# max                        4929.000000        9.600000      5.500000
#
#        A/G Ratio Albumin and Globulin Ratio        Result
# count                          30132.000000  30691.000000
# mean                               0.943467      0.714118
# std                                0.323164      0.451841
# min                                0.300000      0.000000
# 25%                                0.700000      0.000000
# 50%                                0.900000      1.000000
# 75%                                1.100000      1.000000
# max                                2.800000      1.000000

# %%
categories = []
numerical = []
for i in df.columns:
    if(df[i].dtypes == 'object'):
        categories.append(i)
    else:
        numerical.append(i)


print("Categorical Value: \n", categories)
print("\nContinuous Value: \n", numerical)
# Out:
# Categorical Value:
#  ['Gender of the patient']
#
# Continuous Value:
#  ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin', '\xa0Alkphos Alkaline Phosphotase', '\xa0Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase', 'Total Protiens', '\xa0ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio', 'Result']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values Imputation

# %%
df.isnull()
# Out:
#        Age of the patient  Gender of the patient  Total Bilirubin  \
# 0                   False                  False            False
# 1                   False                  False            False
# 2                   False                  False            False
# 3                   False                  False            False
# 4                   False                  False            False
# ...                   ...                    ...              ...
# 30686               False                  False            False
# 30687               False                  False            False
# 30688               False                  False            False
# 30689               False                  False            False
# 30690               False                  False            False
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                 False                          False
# 1                 False                          False
# 2                 False                          False
# 3                 False                          False
# 4                 False                          False
# ...                 ...                            ...
# 30686             False                          False
# 30687             False                          False
# 30688             False                          False
# 30689             False                          False
# 30690             False                          False
#
#         Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                               False                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                               False                            False
# ...                               ...                              ...
# 30686                           False                            False
# 30687                           False                            False
# 30688                           False                            False
# 30689                           False                            False
# 30690                           False                            False
#
#        Total Protiens   ALB Albumin  A/G Ratio Albumin and Globulin Ratio  \
# 0               False         False                                 False
# 1               False         False                                 False
# 2               False         False                                 False
# 3               False         False                                 False
# 4               False         False                                 False
# ...               ...           ...                                   ...
# 30686           False         False                                 False
# 30687           False         False                                 False
# 30688           False         False                                 False
# 30689           False         False                                 False
# 30690           False         False                                 False
#
#        Result
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 30686   False
# 30687   False
# 30688   False
# 30689   False
# 30690   False
#
# [30691 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Age of the patient                        2
# Gender of the patient                   902
# Total Bilirubin                         648
# Direct Bilirubin                        561
#  Alkphos Alkaline Phosphotase           796
#  Sgpt Alamine Aminotransferase          538
# Sgot Aspartate Aminotransferase         462
# Total Protiens                          463
#  ALB Albumin                            494
# A/G Ratio Albumin and Globulin Ratio    559
# Result                                    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5425

# %%
df.shape
# Out:
# (30691, 11)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (27158, 11)

# %%
df.isnull().sum()
# Out:
# Age of the patient                      0
# Gender of the patient                   0
# Total Bilirubin                         0
# Direct Bilirubin                        0
#  Alkphos Alkaline Phosphotase           0
#  Sgpt Alamine Aminotransferase          0
# Sgot Aspartate Aminotransferase         0
# Total Protiens                          0
#  ALB Albumin                            0
# A/G Ratio Albumin and Globulin Ratio    0
# Result                                  0
# dtype: int64

# %% [markdown]
# - As we can see that we have treated all the missing values and now there are no missing values in the dataset.

# %% [markdown]
# ## Outlier Detection and Removal

# %%
categories = []
numerical = []
for i in df.columns:
    if(df[i].dtypes == 'object'):
        categories.append(i)
    else:
        numerical.append(i)


print("Categorical Value: \n", categories)
print("\nContinuous Value: \n", numerical)
# Out:
# Categorical Value:
#  ['Gender of the patient']
#
# Continuous Value:
#  ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin', '\xa0Alkphos Alkaline Phosphotase', '\xa0Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase', 'Total Protiens', '\xa0ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio', 'Result']

# %%
# Check for outlier using multiple boxplot

for column in df:
    if df[column].dtype in ['int64', 'float64']:
        plt.figure()
        df.boxplot(column = [column])

# %%
new_df = df.copy()

# %%
outlier = ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin', '\xa0Alkphos Alkaline Phosphotase', '\xa0Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase', 'Total Protiens', '\xa0ALB Albumin', 'A/G Ratio Albumin and Globulin Ratio', 'Result']

Limits = pd.DataFrame({
    'Feature Name': [],
    'Upper_Limit': [],
    'Lower_Limit': []})

for feature in outlier:
    # Here we are computing the first and third quartile and interquartile range i.e. IQR to compute upper & lower limit
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    iqr = q3 - q1
 
    upper_limit = q3 + (1.5 * iqr)
    lower_limit = q1 - (1.5 * iqr)

    dicts = [{'Feature Name': feature, 'Upper_Limit': upper_limit, 'Lower_Limit': lower_limit}]

    Limits = Limits.append(dicts, ignore_index = True, sort = False)

    # Capping i.e. equating the values of the outlier to their upper and lower limit
    new_df.loc[(new_df[feature]>upper_limit), feature] = upper_limit
    new_df.loc[(new_df[feature]<lower_limit), feature] = lower_limit

print(Limits)
# Out:
#                            Feature Name  Upper_Limit  Lower_Limit
# 0                    Age of the patient        88.00         0.00
# 1                       Total Bilirubin         5.55        -2.05
# 2                      Direct Bilirubin         2.95        -1.45
# 3          Alkphos Alkaline Phosphotase       482.50        -9.50
# 4         Sgpt Alamine Aminotransferase       120.50       -35.50
# 5       Sgot Aspartate Aminotransferase       181.00       -67.00
# 6                        Total Protiens         9.30         3.70
# 7                           ALB Albumin         5.35         0.95
# 8  A/G Ratio Albumin and Globulin Ratio         1.70         0.10
# 9                                Result         2.50        -1.50

# %%
for column in outlier:
    if new_df[column].dtype in ['int64', 'float64']:
        plt.figure()
        plt.title("After Outlier Removal")
        new_df.boxplot(column = [column])

# %% [markdown]
# # EDA

# %%
new_df['Result'].value_counts()
# Out:
# 1.0    19478
# 0.0     7680
# Name: Result, dtype: int64

# %%
new_df['Gender of the patient'].value_counts()
# Out:
# Male      20034
# Female     7124
# Name: Gender of the patient, dtype: int64

# %%
data0=new_df[new_df['Result']==0.0]

data1=new_df[new_df['Result']==1.0]

# %%
fig,axes=plt.subplots(1,2,figsize=(10,5))

sns.histplot(ax=axes[0],x=data0['Age of the patient'])
sns.histplot(ax=axes[1],x=data1["Age of the patient"])
axes[0].set_title("no disease")
axes[1].set_title("disease")
# Out:
# Text(0.5, 1.0, 'disease')

# %%
data1['Gender of the patient'].value_counts()
# Out:
# Male      14374
# Female     5104
# Name: Gender of the patient, dtype: int64

# %%
plt.figure(figsize = (24,40))
sns.countplot(y = 'Age of the patient', data=new_df)
# Out:
# <Axes: xlabel='count', ylabel='Age of the patient'>

# %% [markdown]
# - from the above count plot we can infer that most of the patients are having age between 38 to 58.

# %%
corr = new_df.corr()
corr
# Out:
#                                       Age of the patient  Total Bilirubin  \
# Age of the patient                              1.000000         0.006697
# Total Bilirubin                                 0.006697         1.000000
# Direct Bilirubin                                0.004049         0.985060
#  Alkphos Alkaline Phosphotase                   0.000749         0.351663
#  Sgpt Alamine Aminotransferase                 -0.002390         0.428650
# Sgot Aspartate Aminotransferase                 0.001560         0.527336
# Total Protiens                                 -0.007669        -0.068420
#  ALB Albumin                                   -0.016723        -0.300493
# A/G Ratio Albumin and Globulin Ratio           -0.019415        -0.314713
# Result                                          0.007063         0.311616
#
#                                       Direct Bilirubin  \
# Age of the patient                            0.004049
# Total Bilirubin                               0.985060
# Direct Bilirubin                              1.000000
#  Alkphos Alkaline Phosphotase                 0.358922
#  Sgpt Alamine Aminotransferase                0.425628
# Sgot Aspartate Aminotransferase               0.526625
# Total Protiens                               -0.050864
#  ALB Albumin                                 -0.290072
# A/G Ratio Albumin and Globulin Ratio         -0.317350
# Result                                        0.317729
#
#                                        Alkphos Alkaline Phosphotase  \
# Age of the patient                                         0.000749
# Total Bilirubin                                            0.351663
# Direct Bilirubin                                           0.358922
#  Alkphos Alkaline Phosphotase                              1.000000
#  Sgpt Alamine Aminotransferase                             0.368672
# Sgot Aspartate Aminotransferase                            0.289815
# Total Protiens                                             0.018135
#  ALB Albumin                                              -0.165166
# A/G Ratio Albumin and Globulin Ratio                      -0.294671
# Result                                                     0.234620
#
#                                        Sgpt Alamine Aminotransferase  \
# Age of the patient                                         -0.002390
# Total Bilirubin                                             0.428650
# Direct Bilirubin                                            0.425628
#  Alkphos Alkaline Phosphotase                               0.368672
#  Sgpt Alamine Aminotransferase                              1.000000
# Sgot Aspartate Aminotransferase                             0.773906
# Total Protiens                                              0.020274
#  ALB Albumin                                               -0.020437
# A/G Ratio Albumin and Globulin Ratio                       -0.072727
# Result                                                      0.288217
#
#                                       Sgot Aspartate Aminotransferase  \
# Age of the patient                                           0.001560
# Total Bilirubin                                              0.527336
# Direct Bilirubin                                             0.526625
#  Alkphos Alkaline Phosphotase                                0.289815
#  Sgpt Alamine Aminotransferase                               0.773906
# Sgot Aspartate Aminotransferase                              1.000000
# Total Protiens                                              -0.029585
#  ALB Albumin                                                -0.151914
# A/G Ratio Albumin and Globulin Ratio                        -0.157503
# Result                                                       0.300019
#
#                                       Total Protiens   ALB Albumin  \
# Age of the patient                         -0.007669     -0.016723
# Total Bilirubin                            -0.068420     -0.300493
# Direct Bilirubin                           -0.050864     -0.290072
#  Alkphos Alkaline Phosphotase               0.018135     -0.165166
#  Sgpt Alamine Aminotransferase              0.020274     -0.020437
# Sgot Aspartate Aminotransferase            -0.029585     -0.151914
# Total Protiens                              1.000000      0.776530
#  ALB Albumin                                0.776530      1.000000
# A/G Ratio Albumin and Globulin Ratio        0.245094      0.736027
# Result                                     -0.028215     -0.157538
#
#                                       A/G Ratio Albumin and Globulin Ratio  \
# Age of the patient                                               -0.019415
# Total Bilirubin                                                  -0.314713
# Direct Bilirubin                                                 -0.317350
#  Alkphos Alkaline Phosphotase                                    -0.294671
#  Sgpt Alamine Aminotransferase                                   -0.072727
# Sgot Aspartate Aminotransferase                                  -0.157503
# Total Protiens                                                    0.245094
#  ALB Albumin                                                      0.736027
# A/G Ratio Albumin and Globulin Ratio                              1.000000
# Result                                                           -0.174876
#
#                                         Result
# Age of the patient                    0.007063
# Total Bilirubin                       0.311616
# Direct Bilirubin                      0.317729
#  Alkphos Alkaline Phosphotase         0.234620
#  Sgpt Alamine Aminotransferase        0.288217
# Sgot Aspartate Aminotransferase       0.300019
# Total Protiens                       -0.028215
#  ALB Albumin                         -0.157538
# A/G Ratio Albumin and Globulin Ratio -0.174876
# Result                                1.000000

# %%
# looking at the correlation between numerical variables

mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corr, mask=mask,vmax=.9, square=True,annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# 1. From the above Heat Map we can infer that Total Bilirubin and Direct Bilirubin are positively correlated with the result.
# 2. Total Protien and ALB Albumin are negatively correlated with the result.
# 3. Since "Total Bilirubin" and "Direct Bilirubin" has got strong correlation with each other, during model building any of the feature has to be dropped since they will exhibit multicollinearity in the data.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Encoding the categorical data

# %%
# encoding categorical values
cat_features = ["Gender of the patient"]
new_df = pd.get_dummies(new_df, columns = cat_features)
print(new_df.columns)
# Out:
# Index(['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin',
#        ' Alkphos Alkaline Phosphotase', ' Sgpt Alamine Aminotransferase',
#        'Sgot Aspartate Aminotransferase', 'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'Result',
#        'Gender of the patient_Female', 'Gender of the patient_Male'],
#       dtype='object')

# %%
new_df.head()
# Out:
#    Age of the patient  Total Bilirubin  Direct Bilirubin  \
# 0                65.0             0.70              0.10
# 1                62.0             5.55              2.95
# 2                62.0             5.55              2.95
# 3                58.0             1.00              0.40
# 4                72.0             3.90              2.00
#
#     Alkphos Alkaline Phosphotase   Sgpt Alamine Aminotransferase  \
# 0                          187.0                            16.0
# 1                          482.5                            64.0
# 2                          482.5                            60.0
# 3                          182.0                            14.0
# 4                          195.0                            27.0
#
#    Sgot Aspartate Aminotransferase  Total Protiens   ALB Albumin  \
# 0                             18.0             6.8           3.3
# 1                            100.0             7.5           3.2
# 2                             68.0             7.0           3.3
# 3                             20.0             6.8           3.4
# 4                             59.0             7.3           2.4
#
#    A/G Ratio Albumin and Globulin Ratio  Result  Gender of the patient_Female  \
# 0                                  0.90     1.0                             1
# 1                                  0.74     1.0                             0
# 2                                  0.89     1.0                             0
# 3                                  1.00     1.0                             0
# 4                                  0.40     1.0                             0
#
#    Gender of the patient_Male
# 0                           0
# 1                           1
# 2                           1
# 3                           1
# 4                           1

# %% [markdown]
# # Model Building

# %%
target = new_df['Result']
train = new_df.drop(['Result','Direct Bilirubin'],  axis=1)

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, target, test_size=0.2, random_state=20)

# %% [markdown]
# ## Support Vector Machine

# %%
# Apply SVM Model
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm

svc = SVC()

# %%
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
print('Model accuracy : {0:0.3f}'. format(accuracy_score(y_test, y_pred)))
ac_svm = accuracy_score(y_test, y_pred)
print()
print("Confusion Matrix: ")
print()
cm_svm = cm(y_test, y_pred)
cm_svm
# Out:
# Model accuracy : 0.709
#
# Confusion Matrix:
# array([[   0, 1578],
#        [   0, 3854]], dtype=int64)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lreg = LogisticRegression()

# %%
lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction = lreg.predict(x_test)
print('Model accuracy : {0:0.3f}'. format(accuracy_score(y_test, prediction)))
ac_lr = accuracy_score(y_test, prediction)
print()
print("Confusion Matrix: ")
print()
cm_lr = cm(y_test, prediction)
cm_lr
# Out:
# Model accuracy : 0.715
#
# Confusion Matrix:
# array([[ 306, 1272],
#        [ 275, 3579]], dtype=int64)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
model = clf.fit(x_train, y_train)
model
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
predict = clf.predict(x_test)
print('Model accuracy : {0:0.3f}'. format(accuracy_score(y_test, predict)))
ac_dtc = accuracy_score(y_test, predict)
print()
print("Confusion Matrix: ")
print()
cm_dtc = cm(y_test, predict)
cm_dtc
# Out:
# Model accuracy : 0.738
#
# Confusion Matrix:
# array([[1123,  455],
#        [ 968, 2886]], dtype=int64)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predicted = rfc.predict(x_test)
print('Model accuracy : {0:0.3f}'. format(accuracy_score(y_test, predicted)))
ac_rfc = accuracy_score(y_test, predicted)
print()
print("Confusion Matrix: ")
print()
cm_rfc = cm(y_test, predicted)
cm_rfc
# Out:
# Model accuracy : 1.000
#
# Confusion Matrix:
# array([[1578,    0],
#        [   1, 3853]], dtype=int64)

# %% [markdown]
# #### Comparison of test accuracy of all Four trained models

# %%
print("Support Vector Machine : ",ac_svm)
print("Logistic Regression : ",ac_lr)
print("Decision Tree Classifier : ",ac_dtc)
print("Random Forest Classifier : ", ac_rfc)
# Out:
# Support Vector Machine :  0.709499263622975
# Logistic Regression :  0.7152061855670103
# Decision Tree Classifier :  0.7380338733431517
# Random Forest Classifier :  0.9998159057437408

# %% [markdown]
# #### Comparison of all Four confusion matrices of trained models

# %%
print("\nSupport Vector Machine confusion matrix: ")
print(cm(y_test, y_pred))
print("\nLogistic Regression confusion matrix: ")
print(cm(y_test, prediction))
print("\nDecision Tree Classifier confusion matrix: ")
print(cm(y_test, predict))
print("\nRandom Forest Classifier confusion matrix: ")
print(cm(y_test, predicted))
# Out:
# Support Vector Machine confusion matrix:
# [[   0 1578]
#  [   0 3854]]
#
# Logistic Regression confusion matrix:
# [[ 306 1272]
#  [ 275 3579]]
#
# Decision Tree Classifier confusion matrix:
# [[1123  455]
#  [ 968 2886]]
#
# Random Forest Classifier confusion matrix:
# [[1578    0]
#  [   1 3853]]

# %% [markdown]
# - We can conclude from the accuracy and the confusion matrix that Random Forest Classifier performs best in predicting the both classes.

# %%
# Visualizing confusion matrix as a heatmap

print("\nSupport Vector Machine confusion matrix: ")
plt.figure(figsize=(8, 6))
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1'],
            yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
print()

print("\nLogistic Regression confusion matrix: ")
plt.figure(figsize=(8, 6))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1'],
            yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
print()

print("\nDecision Tree Classifier confusion matrix: ")
plt.figure(figsize=(8, 6))
sns.heatmap(cm_dtc, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1'],
            yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

print("\nRandom Forest Classifier confusion matrix: ")
plt.figure(figsize=(8, 6))
sns.heatmap(cm_rfc, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0', 'Class 1'],
            yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Support Vector Machine confusion matrix:
# Logistic Regression confusion matrix:
# Decision Tree Classifier confusion matrix:
# Random Forest Classifier confusion matrix:

# %%
from sklearn.metrics import roc_curve, auc


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

print("Support Vector Machine")
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

print()
print()
print()
print()
fpr, tpr, thresholds = roc_curve(y_test, prediction)
roc_auc = auc(fpr, tpr)

print("Logistic Regression")
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

print()
print()
print()
print()
fpr, tpr, thresholds = roc_curve(y_test, predict)
roc_auc = auc(fpr, tpr)

print("Decision Tree Classifier")
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

print()
print()
print()
print()
fpr, tpr, thresholds = roc_curve(y_test, predicted)
roc_auc = auc(fpr, tpr)

print("Random Forest Classifier")
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
# Out:
# Support Vector Machine
# Logistic Regression
# Decision Tree Classifier
# Random Forest Classifier

# %% [markdown]
# ### Metrics: Precision, Recall, F1-Score.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision_svc = precision_score(y_test, y_pred)
recall_svc = recall_score(y_test, y_pred)
f1_svc = f1_score(y_test, y_pred)

precision_lr = precision_score(y_test, prediction)
recall_lr = recall_score(y_test, prediction)
f1_lr = f1_score(y_test, prediction)

precision_dtc = precision_score(y_test, predict)
recall_dtc = recall_score(y_test, predict)
f1_dtc = f1_score(y_test, predict)

precision_rfc = precision_score(y_test, predicted)
recall_rfc = recall_score(y_test, predicted)
f1_rfc = f1_score(y_test, predicted)

# %%
# Print the results
print("Support Vector Machine: ")
print()
print(f'Precision: {precision_svc:.4f}')
print(f'Recall: {recall_svc:.4f}')
print(f'F1 Score: {f1_svc:.4f}')

print()
print()
print("Logistic Regression: ")
print()
print(f'Precision: {precision_lr:.4f}')
print(f'Recall: {recall_lr:.4f}')
print(f'F1 Score: {f1_lr:.4f}')

print()
print()
print("Decision Tree Classifier: ")
print()
print(f'Precision: {precision_dtc:.4f}')
print(f'Recall: {recall_dtc:.4f}')
print(f'F1 Score: {f1_dtc:.4f}')

print()
print()
print("Random Forest Classifier: ")
print()
print(f'Precision: {precision_rfc:.4f}')
print(f'Recall: {recall_rfc:.4f}')
print(f'F1 Score: {f1_rfc:.4f}')
# Out:
# Support Vector Machine:
#
# Precision: 0.7095
# Recall: 1.0000
# F1 Score: 0.8301
#
#
# Logistic Regression:
#
# Precision: 0.7378
# Recall: 0.9286
# F1 Score: 0.8223
#
#
# Decision Tree Classifier:
#
# Precision: 0.8638
# Recall: 0.7488
# F1 Score: 0.8022
#
#
# Random Forest Classifier:
#
# Precision: 1.0000
# Recall: 0.9997
# F1 Score: 0.9999

# %% [markdown]
# ## Save the model

# %%
new_df.head(20)
# Out:
#     Age of the patient  Total Bilirubin  Direct Bilirubin  \
# 0                 65.0             0.70              0.10
# 1                 62.0             5.55              2.95
# 2                 62.0             5.55              2.95
# 3                 58.0             1.00              0.40
# 4                 72.0             3.90              2.00
# 5                 46.0             1.80              0.70
# 7                 29.0             0.90              0.30
# 8                 17.0             0.90              0.30
# 9                 55.0             0.70              0.20
# 10                57.0             0.60              0.10
# 11                72.0             2.70              1.30
# 12                64.0             0.90              0.30
# 13                74.0             1.10              0.40
# 14                61.0             0.70              0.20
# 15                25.0             0.60              0.10
# 16                38.0             1.80              0.80
# 17                33.0             1.60              0.50
# 18                40.0             0.90              0.30
# 19                40.0             0.90              0.30
# 20                51.0             2.20              1.00
#
#      Alkphos Alkaline Phosphotase   Sgpt Alamine Aminotransferase  \
# 0                           187.0                            16.0
# 1                           482.5                            64.0
# 2                           482.5                            60.0
# 3                           182.0                            14.0
# 4                           195.0                            27.0
# 5                           208.0                            19.0
# 7                           202.0                            14.0
# 8                           202.0                            22.0
# 9                           290.0                            53.0
# 10                          210.0                            51.0
# 11                          260.0                            31.0
# 12                          310.0                            61.0
# 13                          214.0                            22.0
# 14                          145.0                            53.0
# 15                          183.0                            91.0
# 16                          342.0                           120.5
# 17                          165.0                            15.0
# 18                          293.0                           120.5
# 19                          293.0                           120.5
# 20                          482.5                            17.0
#
#     Sgot Aspartate Aminotransferase  Total Protiens   ALB Albumin  \
# 0                              18.0             6.8           3.3
# 1                             100.0             7.5           3.2
# 2                              68.0             7.0           3.3
# 3                              20.0             6.8           3.4
# 4                              59.0             7.3           2.4
# 5                              14.0             7.6           4.4
# 7                              11.0             6.7           3.6
# 8                              19.0             7.4           4.1
# 9                              58.0             6.8           3.4
# 10                             59.0             5.9           2.7
# 11                             56.0             7.4           3.0
# 12                             58.0             7.0           3.4
# 13                             30.0             8.1           4.1
# 14                             41.0             5.8           2.7
# 15                             53.0             5.5           2.3
# 16                            181.0             7.6           4.4
# 17                             23.0             7.3           3.5
# 18                            181.0             6.8           3.1
# 19                            181.0             6.8           3.1
# 20                             28.0             7.3           2.6
#
#     A/G Ratio Albumin and Globulin Ratio  Result  \
# 0                                   0.90     1.0
# 1                                   0.74     1.0
# 2                                   0.89     1.0
# 3                                   1.00     1.0
# 4                                   0.40     1.0
# 5                                   1.30     1.0
# 7                                   1.10     1.0
# 8                                   1.20     0.0
# 9                                   1.00     1.0
# 10                                  0.80     1.0
# 11                                  0.60     1.0
# 12                                  0.90     0.0
# 13                                  1.00     1.0
# 14                                  0.87     1.0
# 15                                  0.70     0.0
# 16                                  1.30     1.0
# 17                                  0.92     0.0
# 18                                  0.80     1.0
# 19                                  0.80     1.0
# 20                                  0.55     1.0
#
#     Gender of the patient_Female  Gender of the patient_Male
# 0                              1                           0
# 1                              0                           1
# 2                              0                           1
# 3                              0                           1
# 4                              0                           1
# 5                              0                           1
# 7                              1                           0
# 8                              0                           1
# 9                              0                           1
# 10                             0                           1
# 11                             0                           1
# 12                             0                           1
# 13                             1                           0
# 14                             0                           1
# 15                             0                           1
# 16                             0                           1
# 17                             0                           1
# 18                             1                           0
# 19                             1                           0
# 20                             0                           1

# %%
import pickle

# %%
# filename  = 'liverModel.sav'
# pickle.dump(clf, open(filename, 'wb'))

# %%
# filename  = 'clf_liverModel.sav'
# pickle.dump(clf, open(filename, 'wb'))

# filename  = 'rfc_liverModel.sav'
# pickle.dump(rfc, open(filename, 'wb'))

# filename  = 'lreg_liverModel.sav'
# pickle.dump(lreg, open(filename, 'wb'))

# filename  = 'svc_liverModel.sav'
# pickle.dump(svc, open(filename, 'wb'))
